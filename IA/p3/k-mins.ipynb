# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

points = tf.constant(np.random.uniform(0, 5000, (10, 2)))

plt.scatter(points[:, 0], points[:, 1])
plt.show()

# %%
from sklearn.cluster import KMeans

data = list(points)
inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
nr_clusters = input("Please enter nr of clusters:\n")
# Out:
# Please enter nr of clusters:
#  5

# %%
kmeans = KMeans(n_clusters= int(nr_clusters))
kmeans.fit(data)

plt.scatter(points[:, 0], points[:, 1], c=kmeans.labels_)
plt.show()
