# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
import tensorflow as tf

points = tf.constant(np.random.uniform(0, 1000, (100, 2)))

plt.scatter(points[:, 0], points[:, 1])
plt.show()

# %%
data = list(points)
linkage_data = linkage(data, method='single', metric='cityblock')
dendrogram(linkage_data)
plt.show()

# %%
nr_clusters = input("Nr of clusters to form\n")

# %%
hierarchical_cluster = AgglomerativeClustering(n_clusters=int(nr_clusters),affinity='manhattan', linkage='single')
labels = hierarchical_cluster.fit_predict(data)
print(labels)
# Out:
# [0 1 3 0 1 1 1 1 1 1 2 1 0 0 0 0 1 2 4 0 0 1 1 1 0 1 0 0 1 2 0 2 0 0 1 0 1
#  1 1 0 0 1 0 1 1 1 1 0 0 2 0 3 0 1 2 1 1 0 1 1 1 2 2 1 1 2 3 0 1 0 0 0 1 1
#  3 0 0 1 1 1 0 0 0 1 1 0 2 0 1 0 4 0 1 1 1 2 0 2 1 1]

# %%
plt.scatter(points[:, 0], points[:, 1], c=labels)
for i in range(points.shape[0]):
    plt.text(points[i, 0]+0.2, points[i, 1]+0.1, i)
plt.show()
